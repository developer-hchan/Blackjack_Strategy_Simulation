# %% [markdown]
# ### This Notebook Shows how I Generate the Basic Strategy Charts from chart_generation.py and the Exact Expected Values from the Simulation

# %% [markdown]
# Provides a good visual of how I read the data from the .csv's generated from the simulation and wrangle them into dataframes

# %%
# import statements; the %autoreload stuff is just to make sure the modules load in correctly as they can be finicky
# %load_ext autoreload
# %autoreload 2

from pathlib import Path

from blackjack.helper.io import taking_generated_chart_path
from blackjack.helper.io import DEFAULT_CHART_OUTPUT_PATH
from blackjack.helper.io import DEFAULT_DATA_OUTPUT_PATH
from blackjack.helper.io import DEFAULT_DATA_SPLIT_OUTPUT_PATH

import pandas as pd

# %% [markdown]
# \

# %% [markdown]
# Creating the master dataframe that shows all the expected values for...\
# &nbsp;&nbsp;&nbsp;&nbsp;every choice ['hit','stand','double','surrender']\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;for...\
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;every combination of 'player hand total' and 'dealer face up card'

# %%
dataframe = pd.read_csv(DEFAULT_DATA_OUTPUT_PATH)
dataframe.head()
# Out:
#    player hand total player hand texture  dealer face up player choice  \
# 0                 20                hard              11         stand
# 1                 20                hard              11           hit
# 2                 20                hard              11        double
# 3                 20                hard              11     surrender
# 4                 19                hard              11         stand
#
#    expected value
# 0            2.67
# 1          -22.53
# 2          -37.31
# 3          -16.36
# 4           -4.62

# %%
# This organizes the data into a pivot table with an hierarchical index, easier to read

# uncomment the row below to see the entire table
# pd.set_option('display.max_rows', 2000)
master_dataframe = pd.pivot_table(dataframe, values='expected value', index=['player hand texture', 'player hand total', 'dealer face up'], columns=['player choice'])
master_dataframe = master_dataframe.reindex(columns=['hit','double','stand','surrender'])
master_dataframe
# Out:
# player choice                                          hit  double  stand  \
# player hand texture player hand total dealer face up
# hard                4                 2              -2.81  -14.50  -7.41
#                                       3              -1.97  -12.15  -6.17
#                                       4              -1.27  -10.24  -5.13
#                                       5              -0.17   -8.19  -3.67
#                                       6               0.51   -5.91  -2.93
# ...                                                    ...     ...    ...
# soft                20                7               6.28    9.30  19.29
#                                       8               4.81    6.93  19.74
#                                       9               2.87    3.61  19.01
#                                       10             -1.38   -2.39  10.90
#                                       11             -7.19   -8.62   2.72
#
# player choice                                         surrender
# player hand texture player hand total dealer face up
# hard                4                 2                  -12.50
#                                       3                  -12.50
#                                       4                  -12.50
#                                       5                  -12.50
#                                       6                  -12.50
# ...                                                         ...
# soft                20                7                  -12.50
#                                       8                  -12.50
#                                       9                  -12.50
#                                       10                 -13.47
#                                       11                 -16.32
#
# [260 rows x 4 columns]

# %% [markdown]
# \

# %% [markdown]
# Creating the decision matrix for HARD player hand totals\
# I.e. the optimal decision to make for every HARD player total

# %%
hard_dataframe = pd.read_csv(DEFAULT_DATA_OUTPUT_PATH)
hard_dataframe = hard_dataframe[hard_dataframe["player hand texture"] == "hard"]

# this returns the line returns the max expected value for each 'player hand total' and 'dealer face up' combination (from here on referred to as 'case')
hard_dataframe_1 = hard_dataframe.groupby(by=["player hand total","dealer face up"], as_index=False).max("average expected value")
hard_dataframe_1
# Out:
#      player hand total  dealer face up  expected value
# 0                    4               2           -2.81
# 1                    4               3           -1.97
# 2                    4               4           -1.27
# 3                    4               5           -0.17
# 4                    4               6            0.51
# ..                 ...             ...             ...
# 165                 20               7           19.30
# 166                 20               8           19.83
# 167                 20               9           18.97
# 168                 20              10           10.94
# 169                 20              11            2.67
#
# [170 rows x 3 columns]

# %%
# by merging hard_dataframe_1 (the dataset with the max expected value for each case) with the original hard_dataframe (that has all the rows)
# we get a dataframe that has all the original columns, but only the max 'player choice' for each case

# NOTE: In the **rare** instances that there are ties for the max expected values, .drop_duplicates line will delete the second instance...
hard_dataframe_2 = pd.merge(left=hard_dataframe,right=hard_dataframe_1,how='inner').drop_duplicates(["player hand total","dealer face up"])
hard_dataframe_2
# Out:
#      player hand total player hand texture  dealer face up player choice  \
# 0                   20                hard              11         stand
# 1                   19                hard              11         stand
# 2                   18                hard              11         stand
# 3                   17                hard              11     surrender
# 4                   16                hard              11     surrender
# ..                 ...                 ...             ...           ...
# 166                  8                hard               2           hit
# 167                  7                hard               2           hit
# 168                  6                hard               2           hit
# 169                  5                hard               2           hit
# 170                  4                hard               2           hit
#
#      expected value
# 0              2.67
# 1             -4.62
# 2            -11.57
# 3            -16.36
# 4            -16.35
# ..              ...
# 166           -0.43
# 167           -2.75
# 168           -3.43
# 169           -2.99
# 170           -2.81
#
# [170 rows x 5 columns]

# %%
# this cell is reorganizing hard_dataframe_2 (the dataframe we got by merging) to be human-readable-friendly
hard_decision_matrix = hard_dataframe_2.pivot(index='player hand total',columns='dealer face up',values='player choice')
hard_decision_matrix.index.names = ['Player Hard Total']
hard_decision_matrix.columns.names = ['Dealer Face Up']
hard_decision_matrix.rename(columns={11: 'A'}, inplace=True)
hard_decision_matrix
# Out:
# Dealer Face Up          2       3       4       5       6       7       8  \
# Player Hard Total
# 4                     hit     hit     hit     hit     hit     hit     hit
# 5                     hit     hit     hit     hit     hit     hit     hit
# 6                     hit     hit     hit     hit     hit     hit     hit
# 7                     hit     hit     hit     hit     hit     hit     hit
# 8                     hit     hit     hit     hit     hit     hit     hit
# 9                  double  double  double  double  double     hit     hit
# 10                 double  double  double  double  double  double  double
# 11                 double  double  double  double  double  double  double
# 12                    hit     hit   stand   stand   stand     hit     hit
# 13                  stand   stand   stand   stand   stand     hit     hit
# 14                  stand   stand   stand   stand   stand     hit     hit
# 15                  stand   stand   stand   stand   stand     hit     hit
# 16                  stand   stand   stand   stand   stand     hit     hit
# 17                  stand   stand   stand   stand   stand   stand   stand
# 18                  stand   stand   stand   stand   stand   stand   stand
# 19                  stand   stand   stand   stand   stand   stand   stand
# 20                  stand   stand   stand   stand   stand   stand   stand
#
# Dealer Face Up             9         10          A
# Player Hard Total
# 4                        hit        hit        hit
# 5                        hit        hit        hit
# 6                        hit        hit        hit
# 7                        hit        hit        hit
# 8                        hit        hit        hit
# 9                        hit        hit        hit
# 10                    double        hit        hit
# 11                    double     double     double
# 12                       hit        hit        hit
# 13                       hit        hit        hit
# 14                       hit        hit        hit
# 15                       hit        hit  surrender
# 16                 surrender  surrender  surrender
# 17                     stand      stand  surrender
# 18                     stand      stand      stand
# 19                     stand      stand      stand
# 20                     stand      stand      stand

# %% [markdown]
# \

# %% [markdown]
# Creating the decision matrix for SOFT player hand totals\
# I.e. the optimal decision to make for every SOFT player total

# %%
# follow the exact same steps as the hard_dataframe above, except we are extracting the "soft" totals this time
soft_dataframe = pd.read_csv(DEFAULT_DATA_OUTPUT_PATH)
soft_dataframe = soft_dataframe[soft_dataframe["player hand texture"] == "soft"]
soft_dataframe_1 = soft_dataframe.groupby(by=["player hand total","dealer face up"], as_index=False).max("average expected value")
soft_dataframe_2 = pd.merge(left=soft_dataframe,right=soft_dataframe_1,how='inner').drop_duplicates(["player hand total","dealer face up"])
soft_decision_matrix = soft_dataframe_2.pivot(index='player hand total',columns='dealer face up',values='player choice')
soft_decision_matrix
# Out:
# dealer face up        2       3       4       5       6      7      8      9   \
# player hand total
# 12                   hit     hit     hit     hit  double    hit    hit    hit
# 13                   hit     hit     hit  double  double    hit    hit    hit
# 14                   hit     hit     hit  double  double    hit    hit    hit
# 15                   hit     hit     hit  double  double    hit    hit    hit
# 16                   hit     hit  double  double  double    hit    hit    hit
# 17                   hit  double  double  double  double    hit    hit    hit
# 18                 stand  double  double  double  double  stand  stand    hit
# 19                 stand   stand   stand   stand  double  stand  stand  stand
# 20                 stand   stand   stand   stand   stand  stand  stand  stand
#
# dealer face up        10     11
# player hand total
# 12                   hit    hit
# 13                   hit    hit
# 14                   hit    hit
# 15                   hit    hit
# 16                   hit    hit
# 17                   hit    hit
# 18                   hit    hit
# 19                 stand  stand
# 20                 stand  stand

# %%
# this cell is reorganizing soft_decision_matrix to be human-readable-friendly
soft_decision_matrix.rename(index={12: 'A,A', 13: 'A,2', 14: 'A,3', 15: 'A,4', 16: 'A,5', 17: 'A,6', 18: 'A,7', 19: 'A,8', 20: 'A,9'}, inplace= True)
soft_decision_matrix.index.names = ['Player Hand']
soft_decision_matrix.columns.names = ['Dealer Face Up']
soft_decision_matrix.rename(columns={11: 'A'}, inplace=True)
soft_decision_matrix
# Out:
# Dealer Face Up      2       3       4       5       6      7      8      9  \
# Player Hand
# A,A               hit     hit     hit     hit  double    hit    hit    hit
# A,2               hit     hit     hit  double  double    hit    hit    hit
# A,3               hit     hit     hit  double  double    hit    hit    hit
# A,4               hit     hit     hit  double  double    hit    hit    hit
# A,5               hit     hit  double  double  double    hit    hit    hit
# A,6               hit  double  double  double  double    hit    hit    hit
# A,7             stand  double  double  double  double  stand  stand    hit
# A,8             stand   stand   stand   stand  double  stand  stand  stand
# A,9             stand   stand   stand   stand   stand  stand  stand  stand
#
# Dealer Face Up     10      A
# Player Hand
# A,A               hit    hit
# A,2               hit    hit
# A,3               hit    hit
# A,4               hit    hit
# A,5               hit    hit
# A,6               hit    hit
# A,7               hit    hit
# A,8             stand  stand
# A,9             stand  stand

# %% [markdown]
# \

# %% [markdown]
# Creating the decision matrix for SPLIT player hand totals\
# I.e. the optimal decision to make for every SPLIT player total

# %%
# when loading in the split data set, NOTE: this is a different csv than what was used for hard and soft hands, we see that it is organized a bit differently
split = pd.read_csv(DEFAULT_DATA_SPLIT_OUTPUT_PATH)
split.head()
# Out:
#    player hand total player hand texture  dealer face up player choice  \
# 0                 20               split              11         split
# 1                 18               split              11         split
# 2                 16               split              11         split
# 3                 14               split              11         split
# 4                 12               split              11         split
#
#    expected value
# 0          -21.54
# 1          -12.18
# 2          -16.85
# 3          -20.44
# 4          -20.16

# %%
# this cell is unncessary, but it makes the split dataframe more human-readable

# pd.set_option('display.max_rows', 2000)
split_pivot = pd.pivot_table(split, values='expected value', index=['player hand texture', 'player hand total', 'dealer face up'])
split_pivot
# Out:
#                                                       expected value
# player hand texture player hand total dealer face up
# split               2                 2                        12.39
#                                       3                        13.15
#                                       4                        14.51
#                                       5                        15.85
#                                       6                        17.01
# ...                                                              ...
#                     20                7                         3.03
#                                       8                        -5.45
#                                       9                       -14.94
#                                       10                      -18.80
#                                       11                      -21.54
#
# [100 rows x 1 columns]

# %% [markdown]
# To answer the question if we should split or not, we have to compare the expected value we get from the split dataframe and the max associated hard dataframe\
# This is because every splittable hand: {20: 10+10, 18: 9+9, 16: 8+8,... etc} is a hard value hand...\
# &nbsp;&nbsp;&nbsp;&nbsp;with the exception of A,A which is technically a 'soft 12', but that edge case is handled later.\
# \
# For example, if the player has a 7+7, we are going to check the expected value for splitting a 7+7\
# &nbsp;&nbsp;&nbsp;&nbsp;let's say that splitting a 7+7 has an expected value of 5.00\
# Now we will check if the 'hard 14' (which a 7+7 classifies as) optimal / max decision has a higher value than 5.00\
# &nbsp;&nbsp;&nbsp;&nbsp;let's say that the optimal decision for a 'hard 14' is 'stand', and the associated expected value of 'stand' is 4.70\
# \
# In this example, we would say that you should split a 7+7 rather than playing it as a 'hard 14'

# %%
# showing the hard dataframe that contains the optimal / max 'player choice' and associated 'expected value'
hard_dataframe_2
# Out:
#      player hand total player hand texture  dealer face up player choice  \
# 0                   20                hard              11         stand
# 1                   19                hard              11         stand
# 2                   18                hard              11         stand
# 3                   17                hard              11     surrender
# 4                   16                hard              11     surrender
# ..                 ...                 ...             ...           ...
# 166                  8                hard               2           hit
# 167                  7                hard               2           hit
# 168                  6                hard               2           hit
# 169                  5                hard               2           hit
# 170                  4                hard               2           hit
#
#      expected value
# 0              2.67
# 1             -4.62
# 2            -11.57
# 3            -16.36
# 4            -16.35
# ..              ...
# 166           -0.43
# 167           -2.75
# 168           -3.43
# 169           -2.99
# 170           -2.81
#
# [170 rows x 5 columns]

# %%
# using loc we can return the expected value for when we search the hard_dataframe_2 for a certain case: NOTE the return float is technically a series object...
# we'll need to convert it to a float later
hard_dataframe_2.loc[(hard_dataframe_2['player hand total'] == 20) & (hard_dataframe_2['dealer face up'] == 11), "expected value"]
# Out:
# 0    2.67
# Name: expected value, dtype: float64

# %%
# using loc we can return the expected value for when we search the split for a certain case: NOTE the return float is technically a series object...
# we'll need to convert it to a float later
split.loc[(split['player hand total'] == 20) & (split['dealer face up'] == 11), "expected value"]
# Out:
# 0   -21.54
# Name: expected value, dtype: float64

# %%
# these functions perform the case search in their specified dataframe (hard_dataframe_2, split, or soft_dataframe_2) and return the expected value (as a series)
# technically you could just do the search directly in the for loops 2 cells down, but I think using these functions makes it easier to understand what is happening

def hard_search(player_hand_total, dealer_face_up):
    search = hard_dataframe_2.loc[(hard_dataframe_2['player hand total'] == player_hand_total) & (hard_dataframe_2['dealer face up'] == dealer_face_up), "expected value"]
    return search

def split_search(player_hand_total, dealer_face_up):
    search = split.loc[(split['player hand total'] == player_hand_total) & (split['dealer face up'] == dealer_face_up), "expected value"]
    return search

def soft_search(player_hand_total, dealer_face_up):
    search = soft_dataframe_2.loc[(soft_dataframe_2['player hand total'] == player_hand_total) & (soft_dataframe_2['dealer face up'] == dealer_face_up), "expected value"]
    return search

# %%
# just testing that it is returning what we want
# because the search is technically returning a series of length one, we use .iloc[0] to directly extract that value
float(hard_search(20,11).iloc[0])
# Out:
# 2.67

# %%
# these are all the cases we will need to compare
split_numbers = [20,18,16,14,12,10,8,6,4]
dealer_numbers = [11,10,9,8,7,6,5,4,3,2]

# we will be storing the results of the search & compare as List[Tuple]; with the tuple being ('player hand total','dealer face up', 'should you split?')
split_yes_no = []

# comparing the max values from the hard_dataframe_2 and the split dataframe. Storing the values as a tuple and append to a list
for x in dealer_numbers:
    for y in split_numbers:
        if float(split_search(y,x).iloc[0]) > float(hard_search(y,x).iloc[0]):
            split_yes_no.append((y,x,'yes'))
        else:
            split_yes_no.append((y,x,'no'))

# same comparison as above but checking the 'soft 12' case from the soft_dataframe_2; 'soft 12' is A,A and the A,A case is in the soft database not the hard database
for z in dealer_numbers:
    # in split, case A,A is represented by a 'player hand' of 2;;; In soft, case A,A is represented by a 'player hand' of 12
    if float(split_search(player_hand_total=2,dealer_face_up=z).iloc[0]) > float(soft_search(player_hand_total=12,dealer_face_up=z).iloc[0]):
        split_yes_no.append((2,z,'yes'))
    else:
        split_yes_no.append((2,z,'no'))

# just ensuring that the length the list is 100 (it should be 100)
len(split_yes_no)
# Out:
# 100

# %%
# converting the List[Tuple] into a dataframe
split_yes_no_df = pd.DataFrame(split_yes_no, columns=["player hand total","dealer face up","split?"])
split_yes_no_df
# Out:
#     player hand total  dealer face up split?
# 0                  20              11     no
# 1                  18              11     no
# 2                  16              11     no
# 3                  14              11     no
# 4                  12              11     no
# ..                ...             ...    ...
# 95                  2               6    yes
# 96                  2               5    yes
# 97                  2               4    yes
# 98                  2               3    yes
# 99                  2               2    yes
#
# [100 rows x 3 columns]

# %%
# making the dataframe human-readable and in the same form as the previous decision matrices
split_decision_matrix = pd.pivot(split_yes_no_df, index=['player hand total'], columns=['dealer face up'], values=['split?'])

split_decision_matrix.rename(index={2: 'A,A', 4: '2,2', 6: '3,3', 8: '4,4', 10: '5,5', 12: '6,6', 14: '7,7', 16: '8,8', 18: '9,9', 20: '10,10'}, inplace= True)
split_decision_matrix.index.names = ['Player Hand']
split_decision_matrix.rename(columns={11: 'A'}, inplace=True)

# for some reason this removes the ugly 'split?' header caption; I suppose it is technically slicing, but whatever
split_decision_matrix = split_decision_matrix['split?']
split_decision_matrix.columns.names = ['Dealer Face Up']

split_decision_matrix
# Out:
# Dealer Face Up    2    3    4    5    6    7    8    9   10    A
# Player Hand
# A,A             yes  yes  yes  yes  yes  yes  yes  yes  yes  yes
# 2,2             yes  yes  yes  yes  yes  yes  yes   no   no   no
# 3,3             yes  yes  yes  yes  yes  yes   no   no   no   no
# 4,4              no   no   no  yes  yes   no   no   no   no   no
# 5,5              no   no   no   no   no   no   no   no   no   no
# 6,6             yes  yes  yes  yes  yes   no   no   no   no   no
# 7,7             yes  yes  yes  yes  yes  yes   no   no   no   no
# 8,8             yes  yes  yes  yes  yes  yes  yes  yes  yes   no
# 9,9             yes  yes  yes  yes  yes   no  yes  yes   no   no
# 10,10            no   no   no   no   no   no   no   no   no   no

# %% [markdown]
# \

# %% [markdown]
# Styling and Exporting DataFrames to an HTML file

# %%
# this function colors all the player options 'hit','stand','double','surrender'
def color_choice(value):
    color = None
    if value == 'hit':
        color = '#9896f1'
    elif value == 'stand':
        color = '#d59bf6'
    elif value == 'double':
        color = '#edb1f1'
    elif value == 'surrender':
        color = '#6643b5'
    
    return f'background-color: {color}'

# %%
hard_styled = hard_decision_matrix.style.map(color_choice).set_table_attributes('style="border-collapse:collapse"').set_table_styles([
                                                          {"selector": "th",
                                                           "props": [("background-color","#d5eeff"), ("text-align","left"), ('color','black'), ('border','none')]},

                                                          {"selector": "td",
                                                           "props": [("text-align","left"), ('color','black'), ('border','none'), ('width', '75px')]}
])

hard_styled
# Out:
# <style type="text/css">
# #T_c9d7d th {
#   background-color: #d5eeff;
#   text-align: left;
#   color: black;
#   border: none;
# }
# #T_c9d7d td {
#   text-align: left;
#   color: black;
#   border: none;
#   width: 75px;
# }
# #T_c9d7d_row0_col0, #T_c9d7d_row0_col1, #T_c9d7d_row0_col2, #T_c9d7d_row0_col3, #T_c9d7d_row0_col4, #T_c9d7d_row0_col5, #T_c9d7d_row0_col6, #T_c9d7d_row0_col7, #T_c9d7d_row0_col8, #T_c9d7d_row0_col9, #T_c9d7d_row1_col0, #T_c9d7d_row1_col1, #T_c9d7d_row1_col2, #T_c9d7d_row1_col3, #T_c9d7d_row1_col4, #T_c9d7d_row1_col5, #T_c9d7d_row1_col6, #T_c9d7d_row1_col7, #T_c9d7d_row1_col8, #T_c9d7d_row1_col9, #T_c9d7d_row2_col0, #T_c9d7d_row2_col1, #T_c9d7d_row2_col2, #T_c9d7d_row2_col3, #T_c9d7d_row2_col4, #T_c9d7d_row2_col5, #T_c9d7d_row2_col6, #T_c9d7d_row2_col7, #T_c9d7d_row2_col8, #T_c9d7d_row2_col9, #T_c9d7d_row3_col0, #T_c9d7d_row3_col1, #T_c9d7d_row3_col2, #T_c9d7d_row3_col3, #T_c9d7d_row3_col4, #T_c9d7d_row3_col5, #T_c9d7d_row3_col6, #T_c9d7d_row3_col7, #T_c9d7d_row3_col8, #T_c9d7d_row3_col9, #T_c9d7d_row4_col0, #T_c9d7d_row4_col1, #T_c9d7d_row4_col2, #T_c9d7d_row4_col3, #T_c9d7d_row4_col4, #T_c9d7d_row4_col5, #T_c9d7d_row4_col6, #T_c9d7d_row4_col7, #T_c9d7d_row4_col8, #T_c9d7d_row4_col9, #T_c9d7d_row5_col5, #T_c9d7d_row5_col6, #T_c9d7d_row5_col7, #T_c9d7d_row5_col8, #T_c9d7d_row5_col9, #T_c9d7d_row6_col8, #T_c9d7d_row6_col9, #T_c9d7d_row8_col0, #T_c9d7d_row8_col1, #T_c9d7d_row8_col5, #T_c9d7d_row8_col6, #T_c9d7d_row8_col7, #T_c9d7d_row8_col8, #T_c9d7d_row8_col9, #T_c9d7d_row9_col5, #T_c9d7d_row9_col6, #T_c9d7d_row9_col7, #T_c9d7d_row9_col8, #T_c9d7d_row9_col9, #T_c9d7d_row10_col5, #T_c9d7d_row10_col6, #T_c9d7d_row10_col7, #T_c9d7d_row10_col8, #T_c9d7d_row10_col9, #T_c9d7d_row11_col5, #T_c9d7d_row11_col6, #T_c9d7d_row11_col7, #T_c9d7d_row11_col8, #T_c9d7d_row12_col5, #T_c9d7d_row12_col6 {
#   background-color: #9896f1;
# }
# #T_c9d7d_row5_col0, #T_c9d7d_row5_col1, #T_c9d7d_row5_col2, #T_c9d7d_row5_col3, #T_c9d7d_row5_col4, #T_c9d7d_row6_col0, #T_c9d7d_row6_col1, #T_c9d7d_row6_col2, #T_c9d7d_row6_col3, #T_c9d7d_row6_col4, #T_c9d7d_row6_col5, #T_c9d7d_row6_col6, #T_c9d7d_row6_col7, #T_c9d7d_row7_col0, #T_c9d7d_row7_col1, #T_c9d7d_row7_col2, #T_c9d7d_row7_col3, #T_c9d7d_row7_col4, #T_c9d7d_row7_col5, #T_c9d7d_row7_col6, #T_c9d7d_row7_col7, #T_c9d7d_row7_col8, #T_c9d7d_row7_col9 {
#   background-color: #edb1f1;
# }
# #T_c9d7d_row8_col2, #T_c9d7d_row8_col3, #T_c9d7d_row8_col4, #T_c9d7d_row9_col0, #T_c9d7d_row9_col1, #T_c9d7d_row9_col2, #T_c9d7d_row9_col3, #T_c9d7d_row9_col4, #T_c9d7d_row10_col0, #T_c9d7d_row10_col1, #T_c9d7d_row10_col2, #T_c9d7d_row10_col3, #T_c9d7d_row10_col4, #T_c9d7d_row11_col0, #T_c9d7d_row11_col1, #T_c9d7d_row11_col2, #T_c9d7d_row11_col3, #T_c9d7d_row11_col4, #T_c9d7d_row12_col0, #T_c9d7d_row12_col1, #T_c9d7d_row12_col2, #T_c9d7d_row12_col3, #T_c9d7d_row12_col4, #T_c9d7d_row13_col0, #T_c9d7d_row13_col1, #T_c9d7d_row13_col2, #T_c9d7d_row13_col3, #T_c9d7d_row13_col4, #T_c9d7d_row13_col5, #T_c9d7d_row13_col6, #T_c9d7d_row13_col7, #T_c9d7d_row13_col8, #T_c9d7d_row14_col0, #T_c9d7d_row14_col1, #T_c9d7d_row14_col2, #T_c9d7d_row14_col3, #T_c9d7d_row14_col4, #T_c9d7d_row14_col5, #T_c9d7d_row14_col6, #T_c9d7d_row14_col7, #T_c9d7d_row14_col8, #T_c9d7d_row14_col9, #T_c9d7d_row15_col0, #T_c9d7d_row15_col1, #T_c9d7d_row15_col2, #T_c9d7d_row15_col3, #T_c9d7d_row15_col4, #T_c9d7d_row15_col5, #T_c9d7d_row15_col6, #T_c9d7d_row15_col7, #T_c9d7d_row15_col8, #T_c9d7d_row15_col9, #T_c9d7d_row16_col0, #T_c9d7d_row16_col1, #T_c9d7d_row16_col2, #T_c9d7d_row16_col3, #T_c9d7d_row16_col4, #T_c9d7d_row16_col5, #T_c9d7d_row16_col6, #T_c9d7d_row16_col7, #T_c9d7d_row16_col8, #T_c9d7d_row16_col9 {
#   background-color: #d59bf6;
# }
# #T_c9d7d_row11_col9, #T_c9d7d_row12_col7, #T_c9d7d_row12_col8, #T_c9d7d_row12_col9, #T_c9d7d_row13_col9 {
#   background-color: #6643b5;
# }
# </style>
# <table id="T_c9d7d" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Dealer Face Up</th>
#       <th id="T_c9d7d_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_c9d7d_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_c9d7d_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_c9d7d_level0_col3" class="col_heading level0 col3" >5</th>
#       <th id="T_c9d7d_level0_col4" class="col_heading level0 col4" >6</th>
#       <th id="T_c9d7d_level0_col5" class="col_heading level0 col5" >7</th>
#       <th id="T_c9d7d_level0_col6" class="col_heading level0 col6" >8</th>
#       <th id="T_c9d7d_level0_col7" class="col_heading level0 col7" >9</th>
#       <th id="T_c9d7d_level0_col8" class="col_heading level0 col8" >10</th>
#       <th id="T_c9d7d_level0_col9" class="col_heading level0 col9" >A</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Player Hard Total</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9d7d_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_c9d7d_row0_col0" class="data row0 col0" >hit</td>
#       <td id="T_c9d7d_row0_col1" class="data row0 col1" >hit</td>
#       <td id="T_c9d7d_row0_col2" class="data row0 col2" >hit</td>
#       <td id="T_c9d7d_row0_col3" class="data row0 col3" >hit</td>
#       <td id="T_c9d7d_row0_col4" class="data row0 col4" >hit</td>
#       <td id="T_c9d7d_row0_col5" class="data row0 col5" >hit</td>
#       <td id="T_c9d7d_row0_col6" class="data row0 col6" >hit</td>
#       <td id="T_c9d7d_row0_col7" class="data row0 col7" >hit</td>
#       <td id="T_c9d7d_row0_col8" class="data row0 col8" >hit</td>
#       <td id="T_c9d7d_row0_col9" class="data row0 col9" >hit</td>
#     </tr>
#     <tr>
#       <th id="T_c9d7d_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_c9d7d_row1_col0" class="data row1 col0" >hit</td>
#       <td id="T_c9d7d_row1_col1" class="data row1 col1" >hit</td>
#       <td id="T_c9d7d_row1_col2" class="data row1 col2" >hit</td>
#       <td id="T_c9d7d_row1_col3" class="data row1 col3" >hit</td>
#       <td id="T_c9d7d_row1_col4" class="data row1 col4" >hit</td>
#       <td id="T_c9d7d_row1_col5" class="data row1 col5" >hit</td>
#       <td id="T_c9d7d_row1_col6" class="data row1 col6" >hit</td>
#       <td id="T_c9d7d_row1_col7" class="data row1 col7" >hit</td>
#       <td id="T_c9d7d_row1_col8" class="data row1 col8" >hit</td>
#       <td id="T_c9d7d_row1_col9" class="data row1 col9" >hit</td>
#     </tr>
#     <tr>
#       <th id="T_c9d7d_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_c9d7d_row2_col0" class="data row2 col0" >hit</td>
#       <td id="T_c9d7d_row2_col1" class="data row2 col1" >hit</td>
#       <td id="T_c9d7d_row2_col2" class="data row2 col2" >hit</td>
#       <td id="T_c9d7d_row2_col3" class="data row2 col3" >hit</td>
#       <td id="T_c9d7d_row2_col4" class="data row2 col4" >hit</td>
#       <td id="T_c9d7d_row2_col5" class="data row2 col5" >hit</td>
#       <td id="T_c9d7d_row2_col6" class="data row2 col6" >hit</td>
#       <td id="T_c9d7d_row2_col7" class="data row2 col7" >hit</td>
#       <td id="T_c9d7d_row2_col8" class="data row2 col8" >hit</td>
#       <td id="T_c9d7d_row2_col9" class="data row2 col9" >hit</td>
#     </tr>
#     <tr>
#       <th id="T_c9d7d_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_c9d7d_row3_col0" class="data row3 col0" >hit</td>
#       <td id="T_c9d7d_row3_col1" class="data row3 col1" >hit</td>
#       <td id="T_c9d7d_row3_col2" class="data row3 col2" >hit</td>
#       <td id="T_c9d7d_row3_col3" class="data row3 col3" >hit</td>
#       <td id="T_c9d7d_row3_col4" class="data row3 col4" >hit</td>
#       <td id="T_c9d7d_row3_col5" class="data row3 col5" >hit</td>
#       <td id="T_c9d7d_row3_col6" cla

# %%
soft_styled = soft_decision_matrix.style.map(color_choice).set_table_attributes('style="border-collapse:collapse"').set_table_styles([
                                                          {"selector": "th",
                                                           "props": [("background-color","#d5eeff"), ("text-align","left"), ('color','black'), ('border','none')]},

                                                          {"selector": "td",
                                                           "props": [("text-align","left"), ('color','black'), ('border','none'), ('width', '75px')]}
])

soft_styled
# Out:
# <style type="text/css">
# #T_5567e th {
#   background-color: #d5eeff;
#   text-align: left;
#   color: black;
#   border: none;
# }
# #T_5567e td {
#   text-align: left;
#   color: black;
#   border: none;
#   width: 75px;
# }
# #T_5567e_row0_col0, #T_5567e_row0_col1, #T_5567e_row0_col2, #T_5567e_row0_col3, #T_5567e_row0_col5, #T_5567e_row0_col6, #T_5567e_row0_col7, #T_5567e_row0_col8, #T_5567e_row0_col9, #T_5567e_row1_col0, #T_5567e_row1_col1, #T_5567e_row1_col2, #T_5567e_row1_col5, #T_5567e_row1_col6, #T_5567e_row1_col7, #T_5567e_row1_col8, #T_5567e_row1_col9, #T_5567e_row2_col0, #T_5567e_row2_col1, #T_5567e_row2_col2, #T_5567e_row2_col5, #T_5567e_row2_col6, #T_5567e_row2_col7, #T_5567e_row2_col8, #T_5567e_row2_col9, #T_5567e_row3_col0, #T_5567e_row3_col1, #T_5567e_row3_col2, #T_5567e_row3_col5, #T_5567e_row3_col6, #T_5567e_row3_col7, #T_5567e_row3_col8, #T_5567e_row3_col9, #T_5567e_row4_col0, #T_5567e_row4_col1, #T_5567e_row4_col5, #T_5567e_row4_col6, #T_5567e_row4_col7, #T_5567e_row4_col8, #T_5567e_row4_col9, #T_5567e_row5_col0, #T_5567e_row5_col5, #T_5567e_row5_col6, #T_5567e_row5_col7, #T_5567e_row5_col8, #T_5567e_row5_col9, #T_5567e_row6_col7, #T_5567e_row6_col8, #T_5567e_row6_col9 {
#   background-color: #9896f1;
# }
# #T_5567e_row0_col4, #T_5567e_row1_col3, #T_5567e_row1_col4, #T_5567e_row2_col3, #T_5567e_row2_col4, #T_5567e_row3_col3, #T_5567e_row3_col4, #T_5567e_row4_col2, #T_5567e_row4_col3, #T_5567e_row4_col4, #T_5567e_row5_col1, #T_5567e_row5_col2, #T_5567e_row5_col3, #T_5567e_row5_col4, #T_5567e_row6_col1, #T_5567e_row6_col2, #T_5567e_row6_col3, #T_5567e_row6_col4, #T_5567e_row7_col4 {
#   background-color: #edb1f1;
# }
# #T_5567e_row6_col0, #T_5567e_row6_col5, #T_5567e_row6_col6, #T_5567e_row7_col0, #T_5567e_row7_col1, #T_5567e_row7_col2, #T_5567e_row7_col3, #T_5567e_row7_col5, #T_5567e_row7_col6, #T_5567e_row7_col7, #T_5567e_row7_col8, #T_5567e_row7_col9, #T_5567e_row8_col0, #T_5567e_row8_col1, #T_5567e_row8_col2, #T_5567e_row8_col3, #T_5567e_row8_col4, #T_5567e_row8_col5, #T_5567e_row8_col6, #T_5567e_row8_col7, #T_5567e_row8_col8, #T_5567e_row8_col9 {
#   background-color: #d59bf6;
# }
# </style>
# <table id="T_5567e" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Dealer Face Up</th>
#       <th id="T_5567e_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_5567e_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_5567e_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_5567e_level0_col3" class="col_heading level0 col3" >5</th>
#       <th id="T_5567e_level0_col4" class="col_heading level0 col4" >6</th>
#       <th id="T_5567e_level0_col5" class="col_heading level0 col5" >7</th>
#       <th id="T_5567e_level0_col6" class="col_heading level0 col6" >8</th>
#       <th id="T_5567e_level0_col7" class="col_heading level0 col7" >9</th>
#       <th id="T_5567e_level0_col8" class="col_heading level0 col8" >10</th>
#       <th id="T_5567e_level0_col9" class="col_heading level0 col9" >A</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Player Hand</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5567e_level0_row0" class="row_heading level0 row0" >A,A</th>
#       <td id="T_5567e_row0_col0" class="data row0 col0" >hit</td>
#       <td id="T_5567e_row0_col1" class="data row0 col1" >hit</td>
#       <td id="T_5567e_row0_col2" class="data row0 col2" >hit</td>
#       <td id="T_5567e_row0_col3" class="data row0 col3" >hit</td>
#       <td id="T_5567e_row0_col4" class="data row0 col4" >double</td>
#       <td id="T_5567e_row0_col5" class="data row0 col5" >hit</td>
#       <td id="T_5567e_row0_col6" class="data row0 col6" >hit</td>
#       <td id="T_5567e_row0_col7" class="data row0 col7" >hit</td>
#       <td id="T_5567e_row0_col8" class="data row0 col8" >hit</td>
#       <td id="T_5567e_row0_col9" class="data row0 col9" >hit</td>
#     </tr>
#     <tr>
#       <th id="T_5567e_level0_row1" class="row_heading level0 row1" >A,2</th>
#       <td id="T_5567e_row1_col0" class="data row1 col0" >hit</td>
#       <td id="T_5567e_row1_col1" class="data row1 col1" >hit</td>
#       <td id="T_5567e_row1_col2" class="data row1 col2" >hit</td>
#       <td id="T_5567e_row1_col3" class="data row1 col3" >double</td>
#       <td id="T_5567e_row1_col4" class="data row1 col4" >double</td>
#       <td id="T_5567e_row1_col5" class="data row1 col5" >hit</td>
#       <td id="T_5567e_row1_col6" class="data row1 col6" >hit</td>
#       <td id="T_5567e_row1_col7" class="data row1 col7" >hit</td>
#       <td id="T_5567e_row1_col8" class="data row1 col8" >hit</td>
#       <td id="T_5567e_row1_col9" class="data row1 col9" >hit</td>
#     </tr>
#     <tr>
#       <th id="T_5567e_level0_row2" class="row_heading level0 row2" >A,3</th>
#       <td id="T_5567e_row2_col0" class="data row2 col0" >hit</td>
#       <td id="T_5567e_row2_col1" class="data row2 col1" >hit</td>
#       <td id="T_5567e_row2_col2" class="data row2 col2" >hit</td>
#       <td id="T_5567e_row2_col3" class="data row2 col3" >double</td>
#       <td id="T_5567e_row2_col4" class="data row2 col4" >double</td>
#       <td id="T_5567e_row2_col5" class="data row2 col5" >hit</td>
#       <td id="T_5567e_row2_col6" class="data row2 col6" >hit</td>
#       <td id="T_5567e_row2_col7" class="data row2 col7" >hit</td>
#       <td id="T_5567e_row2_col8" class="data row2 col8" >hit</td>
#       <td id="T_5567e_row2_col9" class="data row2 col9" >hit</td>
#     </tr>
#     <tr>
#       <th id="T_5567e_level0_row3" class="row_heading level0 row3" >A,4</th>
#       <td id="T_5567e_row3_col0" class="data row3 col0" >hit</td>
#       <td id="T_5567e_row3_col1" class="data row3 col1" >hit</td>
#       <td id="T_5567e_row3_col2" class="data row3 col2" >hit</td>
#       <td id="T_5567e_row3_col3" class="data row3 col3" >double</td>
#       <td id="T_5567e_row3_col4" class="data row3 col4" >double</td>
#       <td id="T_5567e_row3_col5" class="data row3 col5" >hit</td>
#       <td id="T_5567e_row3_col6" class="data row3 col6" >hit</td>
#       <td id="T_5567e_row3_col7" class="data row3 col7" >hit</td>
#       <td id="T_5567e_row3_col8" class="data row3 col8" >hit</td>
#       <td id="T_5567e_row3_col9" class="data row3 col9" >hit</td>
#     </tr>
#     <tr>
#       <th id="T_5567e_level0_row4" class="row_heading level0 row4" >A,5</th>
#       <td id="T_5567e_row4_col0" class="data row4 col0" >hit</td>
#       <td id="T_5567e_row4_col1" class="data row4 col1" >hit</td>
#       <td id="T_5567e_row4_col2" class="data row4 col2" >double</td>
#       <td id="T_5567e_row4_col3" class="data row4 col3" >double</td>
#       <td id="T_5567e_row4_col4" class="data row4 col4" >double</td>
#       <td id="T_5567e_row4_col5" class="data row4 col5" >hit</td>
#       <td id="T_5567e_row4_col6" class="data row4 col6" >hit</td>
#       <td id="T_5567e_row4_col7" class="data row4 col7" >hit</td>
#       <td id="T_5567e_row4_col8" class="data row4 col8" >hit</td>
#       <td id="T_5567e_row4_col9" class="data row4 col9" >hit</td>
#     </tr>
#     <tr>
#       <th id="T_5567e_level0_row5" class="row_heading level0 row5" >A,6</th>
#       <td id="T_5567e_row5_col0" class="data row5 col0" >hit</td>
#       <td id="T_5567e_row5_col1" class="data row5 col1" >double</td>
#       <td id="T_5567e_row5_col2" class="data row5 col2" >double</td>
#       <td id="T_5567e_row5_col3" class="data row5 col3" >double</td>
#       <td id="T_5567e_row5_col4" class="data row5 col4" >double</td>
#       <td id="T_5567e_row5_col5" class="data row5 col5" >hit</td>
#       <td id="T_5567e_row5_col6" class="data row5 col6" >hit</td>
#       <td id="T_5567e_row5_col7" class="data row5 col7" >hit</td>
#       <td id="T_5567e_row5_col8" class="data row5

# %%
# this function colors all the player options 'hit','stand','double','surrender'
def split_color_choice(value):
    color = None
    if value == 'no':
        color = '#d59bf6'
    elif value == 'yes':
        color = '#edb1f1'
    
    return f'background-color: {color}'

# %%
split_styled = split_decision_matrix.style.map(split_color_choice).set_table_attributes('style="border-collapse:collapse"').set_table_styles([
                                                          {"selector": "th",
                                                           "props": [("background-color","#d5eeff"), ("text-align","left"), ('color','black'), ('border','none')]},

                                                          {"selector": "td",
                                                           "props": [("text-align","left"), ('color','black'), ('border','none'), ('width', '75px')]}
])

split_styled
# Out:
# <style type="text/css">
# #T_42a16 th {
#   background-color: #d5eeff;
#   text-align: left;
#   color: black;
#   border: none;
# }
# #T_42a16 td {
#   text-align: left;
#   color: black;
#   border: none;
#   width: 75px;
# }
# #T_42a16_row0_col0, #T_42a16_row0_col1, #T_42a16_row0_col2, #T_42a16_row0_col3, #T_42a16_row0_col4, #T_42a16_row0_col5, #T_42a16_row0_col6, #T_42a16_row0_col7, #T_42a16_row0_col8, #T_42a16_row0_col9, #T_42a16_row1_col0, #T_42a16_row1_col1, #T_42a16_row1_col2, #T_42a16_row1_col3, #T_42a16_row1_col4, #T_42a16_row1_col5, #T_42a16_row1_col6, #T_42a16_row2_col0, #T_42a16_row2_col1, #T_42a16_row2_col2, #T_42a16_row2_col3, #T_42a16_row2_col4, #T_42a16_row2_col5, #T_42a16_row3_col3, #T_42a16_row3_col4, #T_42a16_row5_col0, #T_42a16_row5_col1, #T_42a16_row5_col2, #T_42a16_row5_col3, #T_42a16_row5_col4, #T_42a16_row6_col0, #T_42a16_row6_col1, #T_42a16_row6_col2, #T_42a16_row6_col3, #T_42a16_row6_col4, #T_42a16_row6_col5, #T_42a16_row7_col0, #T_42a16_row7_col1, #T_42a16_row7_col2, #T_42a16_row7_col3, #T_42a16_row7_col4, #T_42a16_row7_col5, #T_42a16_row7_col6, #T_42a16_row7_col7, #T_42a16_row7_col8, #T_42a16_row8_col0, #T_42a16_row8_col1, #T_42a16_row8_col2, #T_42a16_row8_col3, #T_42a16_row8_col4, #T_42a16_row8_col6, #T_42a16_row8_col7 {
#   background-color: #edb1f1;
# }
# #T_42a16_row1_col7, #T_42a16_row1_col8, #T_42a16_row1_col9, #T_42a16_row2_col6, #T_42a16_row2_col7, #T_42a16_row2_col8, #T_42a16_row2_col9, #T_42a16_row3_col0, #T_42a16_row3_col1, #T_42a16_row3_col2, #T_42a16_row3_col5, #T_42a16_row3_col6, #T_42a16_row3_col7, #T_42a16_row3_col8, #T_42a16_row3_col9, #T_42a16_row4_col0, #T_42a16_row4_col1, #T_42a16_row4_col2, #T_42a16_row4_col3, #T_42a16_row4_col4, #T_42a16_row4_col5, #T_42a16_row4_col6, #T_42a16_row4_col7, #T_42a16_row4_col8, #T_42a16_row4_col9, #T_42a16_row5_col5, #T_42a16_row5_col6, #T_42a16_row5_col7, #T_42a16_row5_col8, #T_42a16_row5_col9, #T_42a16_row6_col6, #T_42a16_row6_col7, #T_42a16_row6_col8, #T_42a16_row6_col9, #T_42a16_row7_col9, #T_42a16_row8_col5, #T_42a16_row8_col8, #T_42a16_row8_col9, #T_42a16_row9_col0, #T_42a16_row9_col1, #T_42a16_row9_col2, #T_42a16_row9_col3, #T_42a16_row9_col4, #T_42a16_row9_col5, #T_42a16_row9_col6, #T_42a16_row9_col7, #T_42a16_row9_col8, #T_42a16_row9_col9 {
#   background-color: #d59bf6;
# }
# </style>
# <table id="T_42a16" style="border-collapse:collapse">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Dealer Face Up</th>
#       <th id="T_42a16_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_42a16_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_42a16_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_42a16_level0_col3" class="col_heading level0 col3" >5</th>
#       <th id="T_42a16_level0_col4" class="col_heading level0 col4" >6</th>
#       <th id="T_42a16_level0_col5" class="col_heading level0 col5" >7</th>
#       <th id="T_42a16_level0_col6" class="col_heading level0 col6" >8</th>
#       <th id="T_42a16_level0_col7" class="col_heading level0 col7" >9</th>
#       <th id="T_42a16_level0_col8" class="col_heading level0 col8" >10</th>
#       <th id="T_42a16_level0_col9" class="col_heading level0 col9" >A</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Player Hand</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42a16_level0_row0" class="row_heading level0 row0" >A,A</th>
#       <td id="T_42a16_row0_col0" class="data row0 col0" >yes</td>
#       <td id="T_42a16_row0_col1" class="data row0 col1" >yes</td>
#       <td id="T_42a16_row0_col2" class="data row0 col2" >yes</td>
#       <td id="T_42a16_row0_col3" class="data row0 col3" >yes</td>
#       <td id="T_42a16_row0_col4" class="data row0 col4" >yes</td>
#       <td id="T_42a16_row0_col5" class="data row0 col5" >yes</td>
#       <td id="T_42a16_row0_col6" class="data row0 col6" >yes</td>
#       <td id="T_42a16_row0_col7" class="data row0 col7" >yes</td>
#       <td id="T_42a16_row0_col8" class="data row0 col8" >yes</td>
#       <td id="T_42a16_row0_col9" class="data row0 col9" >yes</td>
#     </tr>
#     <tr>
#       <th id="T_42a16_level0_row1" class="row_heading level0 row1" >2,2</th>
#       <td id="T_42a16_row1_col0" class="data row1 col0" >yes</td>
#       <td id="T_42a16_row1_col1" class="data row1 col1" >yes</td>
#       <td id="T_42a16_row1_col2" class="data row1 col2" >yes</td>
#       <td id="T_42a16_row1_col3" class="data row1 col3" >yes</td>
#       <td id="T_42a16_row1_col4" class="data row1 col4" >yes</td>
#       <td id="T_42a16_row1_col5" class="data row1 col5" >yes</td>
#       <td id="T_42a16_row1_col6" class="data row1 col6" >yes</td>
#       <td id="T_42a16_row1_col7" class="data row1 col7" >no</td>
#       <td id="T_42a16_row1_col8" class="data row1 col8" >no</td>
#       <td id="T_42a16_row1_col9" class="data row1 col9" >no</td>
#     </tr>
#     <tr>
#       <th id="T_42a16_level0_row2" class="row_heading level0 row2" >3,3</th>
#       <td id="T_42a16_row2_col0" class="data row2 col0" >yes</td>
#       <td id="T_42a16_row2_col1" class="data row2 col1" >yes</td>
#       <td id="T_42a16_row2_col2" class="data row2 col2" >yes</td>
#       <td id="T_42a16_row2_col3" class="data row2 col3" >yes</td>
#       <td id="T_42a16_row2_col4" class="data row2 col4" >yes</td>
#       <td id="T_42a16_row2_col5" class="data row2 col5" >yes</td>
#       <td id="T_42a16_row2_col6" class="data row2 col6" >no</td>
#       <td id="T_42a16_row2_col7" class="data row2 col7" >no</td>
#       <td id="T_42a16_row2_col8" class="data row2 col8" >no</td>
#       <td id="T_42a16_row2_col9" class="data row2 col9" >no</td>
#     </tr>
#     <tr>
#       <th id="T_42a16_level0_row3" class="row_heading level0 row3" >4,4</th>
#       <td id="T_42a16_row3_col0" class="data row3 col0" >no</td>
#       <td id="T_42a16_row3_col1" class="data row3 col1" >no</td>
#       <td id="T_42a16_row3_col2" class="data row3 col2" >no</td>
#       <td id="T_42a16_row3_col3" class="data row3 col3" >yes</td>
#       <td id="T_42a16_row3_col4" class="data row3 col4" >yes</td>
#       <td id="T_42a16_row3_col5" class="data row3 col5" >no</td>
#       <td id="T_42a16_row3_col6" class="data row3 col6" >no</td>
#       <td id="T_42a16_row3_col7" class="data row3 col7" >no</td>
#       <td id="T_42a16_row3_col8" class="data row3 col8" >no</td>
#       <td id="T_42a16_row3_col9" class="data row3 col9" >no</td>
#     </tr>
#     <tr>
#       <th id="T_42a16_level0_row4" class="row_heading level0 row4" >5,5</th>
#       <td id="T_42a16_row4_col0" class="data row4 col0" >no</td>
#       <td id="T_42a16_row4_col1" class="data row4 col1" >no</td>
#       <td id="T_42a16_row4_col2" class="data row4 col2" >no</td>
#       <td id="T_42a16_row4_col3" class="data row4 col3" >no</td>
#       <td id="T_42a16_row4_col4" class="data row4 col4" >no</td>
#       <td id="T_42a16_row4_col5" class="data row4 col5" >no</td>
#       <td id="T_42a16_row4_col6" class="data row4 col6" >no</td>
#       <td id="T_42a16_row4_col7" class="data row4 col7" >no</td>
#       <td id="T_42a16_row4_col8" class="data row4 col8" >no</td>
#       <td id="T_42a16_row4_col9" class="data row4 col9" >no</td>
#     </tr>
#     <tr>
#       <th id="T_42a16_level0_row5" class="row_heading level0 row5" >6,6</th>
#       <td id="T_42a16_row5_col0" class="data row5 col0" >yes</td>
#       <td id="T_42a16_row5_col1" class="data row5 col1" >yes</td>
#       <td id="T_42a16_row5_col2" class="data row5 col2" >yes</td>
#       <td id="T_42a16_row5_col3" class="data row5 col3" >yes</td>
#       <td id="T_42a16_row5_col4" class="data row5 col4" >yes</td>
#       <td id="T_42a16_row5_col5" class="data row5 col5" >no</td>
#       <td id="T_42a16_row5_col6" class="data row5 col6" >no</td>
#       <td id="T_4

# %% [markdown]
# Uncomment the cell below to create an HTML basic strategy chart from this notebook; though main.py already creates one after a running a simulation

# %%
#taking_generated_chart_path(file_path=DEFAULT_CHART_OUTPUT_PATH, hard_styled=hard_styled, soft_styled=soft_styled, split_styled=split_styled, rules_styled=rules_styled)
