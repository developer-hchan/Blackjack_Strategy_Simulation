# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np

# %%
dataframe = pd.read_csv("data.csv")
dataframe.head()
# Out:
#    player hand total player hand texture  dealer face up player choice  \
# 0                 20                hard              11           hit
# 1                 20                hard              11         stand
# 2                 20                hard              11        double
# 3                 20                hard              11     surrender
# 4                 19                hard              11           hit
#
#    expected value
# 0          -25.00
# 1            2.14
# 2          -41.78
# 3          -16.67
# 4          -22.62

# %%
# pd.set_option('display.max_rows', 2000)
dataframe_pivot = pd.pivot_table(dataframe, values='expected value', index=['player hand texture', 'player hand total', 'dealer face up'], columns=['player choice'])
dataframe_pivot = dataframe_pivot.reindex(columns=['hit','double','stand','surrender'])
dataframe_pivot
# Out:
# player choice                                          hit  double  stand  \
# player hand texture player hand total dealer face up
# hard                4                 2              -2.35  -11.89  -6.51
#                                       3              -1.70  -11.32  -5.54
#                                       4              -1.09   -9.13  -4.60
#                                       5              -0.23   -6.67  -3.56
#                                       6               1.47   -1.90  -1.09
# ...                                                    ...     ...    ...
# soft                20                7               5.39    8.20  19.00
#                                       8               3.94    5.17  19.48
#                                       9               2.34    2.79  20.30
#                                       10             -1.31   -4.45  13.99
#                                       11             -8.90  -11.38   1.75
#
# player choice                                         surrender
# player hand texture player hand total dealer face up
# hard                4                 2                  -12.50
#                                       3                  -12.50
#                                       4                  -12.50
#                                       5                  -12.50
#                                       6                  -12.50
# ...                                                         ...
# soft                20                7                  -12.50
#                                       8                  -12.50
#                                       9                  -12.50
#                                       10                 -12.50
#                                       11                 -16.72
#
# [260 rows x 4 columns]

# %%
split = pd.read_csv("data_split.csv")
split.head()
# Out:
#    player hand total player hand texture  dealer face up player choice  \
# 0                 20          split hand              11         split
# 1                 18          split hand              11         split
# 2                 16          split hand              11         split
# 3                 14          split hand              11         split
# 4                 12          split hand              11         split
#
#    expected value
# 0          -31.74
# 1          -14.02
# 2          -18.52
# 3          -21.07
# 4          -20.51

# %%
pd.set_option('display.max_rows', 2000)
split_pivot = pd.pivot_table(split, values='expected value', index=['player hand texture', 'player hand total', 'dealer face up'])
split_pivot
# Out:
#                                                       expected value
# player hand texture player hand total dealer face up
# split hand          2                 2                        14.72
#                                       3                        15.99
#                                       4                        17.63
#                                       5                        18.05
#                                       6                        20.12
#                                       7                        15.75
#                                       8                        13.36
#                                       9                        10.36
#                                       10                        7.02
#                                       11                       -5.36
#                     4                 2                        -2.04
#                                       3                        -0.55
#                                       4                         1.83
#                                       5                         2.76
#                                       6                         8.22
#                                       7                        -0.09
#                                       8                        -3.56
#                                       9                        -8.39
#                                       10                      -14.06
#                                       11                      -18.08
#                     6                 2                        -3.01
#                                       3                        -0.83
#                                       4                         0.86
#                                       5                         4.49
#                                       6                         8.37
#                                       7                        -1.52
#                                       8                        -4.59
#                                       9                       -10.43
#                                       10                      -14.65
#                                       11                      -18.96
#                     8                 2                        -3.86
#                                       3                        -2.58
#                                       4                         0.62
#                                       5                         2.40
#                                       6                         7.91
#                                       7                        -4.20
#                                       8                        -8.44
#                                       9                       -11.89
#                                       10                      -16.43
#                                       11                      -20.17
#                     10                2                        -6.46
#                                       3                        -3.92
#                                       4                        -1.25
#                                       5                         0.11
#                                       6                         5.06
#                                       7                        -7.06
#                                       8                       -11.21
#                                       9                       -15.80
#                                       10                      -19.06
#                                       11                      -21.73
#                     12                2                        -4.33
#                                       3                        -2.04
#                                       4                         1.22
#                                       5                         2.98
#                                       6                         7.14
#                                       7                        -7.70
#                                       8                       -10.42
#                                       9                       -14.69
#                                       10                      -18.49
#                                       11                      -20.51
#                     14                2                        -2.96
#                                       3                        -1.21
#                                       4                         1.27
#                                       5                         3.96
#                                       6                         8.87
#                                       7                        -1.51
#                                       8                        -8.70
#                                       9                       -13.37
#                                       10                      -17.53
#                                       11                      -21.07
#                     16                2                         1.92
#                                       3                         3.08
#                                       4                         6.36
#                                       5                         7.33
#                                       6                        10.00
#                                       7                         7.62
#                                       8                        -0.25
#                                       9                        -8.95
#                                       10                      -13.34
#                                       11                      -18.52
#                     18                2                         3.78
#                                       3                         5.74
#                                       4                         7.25
#                                       5                         8.70
#                                       6                        12.78
#                                       7                         7.04
#                                       8                         5.00
#                                       9                        -2.82
#                                       10                      -10.88
#                                       11                      -14.02
#                     20                2                        -9.86
#                                       3                        -7.98
#                                       4                        -3.85
#                                       5                        -1.25
#                                       6                         6.51
#                                       7                        -6.89
#                                       8                       -15.40
#                                       9                       -26.61
#                                       10                      -35.72
#                                       11                      -31.74
